# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

import re
import copy

# %%
# %matplotlib inline

# %%
df = pd.read_csv('./intermediate_datafiles/result.csv')
df.head()
# Out:
#                       Unnamed: 0     acc_z     acc_y     acc_x  \
# 0  2025-06-06 16:58:25.812088800 -0.228476  0.150044 -0.000168
# 1  2025-06-06 16:59:25.812088800 -0.152335  0.193268 -0.015586
# 2  2025-06-06 17:00:25.812088800 -0.121249  0.153527  0.086347
# 3  2025-06-06 17:01:25.812088800 -0.152177  0.149542  0.115026
# 4  2025-06-06 17:02:25.812088800 -0.231471  0.236214  0.030241
#
#    seconds_elapsed    gyro_z    gyro_y    gyro_x    grav_z    grav_y  ...  \
# 0        42.273264 -0.047914 -0.106186  0.045188 -0.682844  5.978657  ...
# 1        89.166121  0.059801  0.001418 -0.011066  0.202307  9.448945  ...
# 2       149.999454  0.042315 -0.000596 -0.010449  0.516053  9.633063  ...
# 3       209.916121  0.045572 -0.019458  0.001071  0.545082  9.626150  ...
# 4       269.082788  0.031153 -0.033805  0.008958 -0.281100  8.804954  ...
#
#    wrist_accelerationX  wrist_accelerationY  wrist_accelerationZ  \
# 0            -0.054646             0.030263             0.042182
# ...

# %%
import matplotlib.pyplot as plt

cols = [
    'acc_x', 'acc_y', 'acc_z',                      # phone accelerometer
    'wrist_accelerationX', 'wrist_accelerationY', 'wrist_accelerationZ'  # watch accelerometer
]


df[cols].plot(figsize=(12, 5))
plt.title("Phone vs Wrist Accelerometer")
plt.ylabel("Acceleration (m/s²)")
plt.xlabel("Time")
plt.legend(loc='upper right')
plt.show()
